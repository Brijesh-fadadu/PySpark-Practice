# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 281.3 MB 43 kB/s
# ...
#      |████████████████████████████████| 199 kB 46.8 MB/s
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.0-py2.py3-none-any.whl size=281764026 sha256=601688d97eca04d61d158f2836f8dcdee8266b560577642f610ead700fcf2a29
#   Stored in directory: /root/.cache/pip/wheels/7a/8e/1b/f73a52650d2e5f337708d9f6a1750d451a7349a867f928b885
# Successfully built pyspark
# ...

# %%
# !pip install spark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 62 kB/s
# ...
#   Created wheel for spark: filename=spark-0.2.1-py3-none-any.whl size=58762 sha256=7e368467c729abfeb817caeee333e8432965d0b8b409bcbfbc0b7948269a9394
#   Stored in directory: /root/.cache/pip/wheels/4e/0e/f1/164619f9920fb447d294afaae11a7715bd442ded7225953d72
# Successfully built spark
# ...

# %%
# !pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy
from tweepy import OAuthHandler, Stream

# %%
from tweepy.streaming import StreamListener
import socket
import json

# %%
consumer_key = 'YTP9mwEfeeEwoiDWYy95B0eVV'
consumer_secret = '13cKgk8szHh09OqUZvoRWYjJXMM6JG5Rn3BCAMwHxnfQygAQzE'
access_token = '1273847462709440513-JQIgjsTQsxSVgovJn2JA2DGmGSiMZW'
access_secret = '7P9P9JZWcjiAn3VtmUVIMy9gkwQR7xUvxlmsfUmLqLjkP'

# %%
class TweetListener(StreamListener):

  def __init__(self,csocket):
    self.client_socket = csocket

  def on_data(self,data):

      try:
         msg = json.loads(data)
         print(msg['text'].encode('utf-8'))
         self.client_socket.send(msg['text'].encode('utf-8'))
         return True
      except BaseException as e:
         print('ERROR', e)
      return True


  def on_error(self, status):
    print(status)
    return True

# %%
def sendData(c_socket):
  auth = OAuthHandler(consumer_key,consumer_secret)
  auth.set_access_token(access_token,access_secret)

  twitter_stream = Stream(auth, TweetListener(c_socket))
  twitter_stream.filter(track=['india'])

# %%
if __name__ == '__main__':
  s = socket.socket()
  host = '127.0.0.1'
  port = 9998
  s.bind((host,port))

  print('Listining on port 99998')

  s.listen(5)
  c,addr = s.accept()

  sendData(c)
# Out:
# Listining on port 99998
